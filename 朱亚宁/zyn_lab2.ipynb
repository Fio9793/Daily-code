# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
primitive_data=pd.read_csv("Pokemon.csv",encoding="latin_1")
primitive_data
# Out:
#              #                       Name     Type 1     Type 2      Total  \
# 0            1                  Bulbasaur      Grass     Poison        318
# 1            2                    Ivysaur      Grass     Poison        405
# 2            3                   Venusaur      Grass     Poison        525
# 3            3      VenusaurMega Venusaur      Grass     Poison        625
# 4            4                 Charmander       Fire        NaN        309
# 5            5                 Charmeleon       Fire        NaN        405
# 6            6                  Charizard       Fire     Flying        534
# 7            6  CharizardMega Charizard X       Fire     Dragon        634
# 8            6  CharizardMega Charizard Y       Fire     Flying        634
# 9            7                   Squirtle      Water        NaN        314
# 10           8                  Wartortle      Water        NaN        405
# 11           9                  Blastoise      Water        NaN        530
# 12           9    BlastoiseMega Blastoise      Water        NaN        630
# 13          10                   Caterpie        Bug        NaN        195
# 14          11                    Metapod        Bug        NaN        205
# 15          11                    Metapod        Bug        NaN        205
# 16          12                 Butterfree        Bug     Flying        395
# 17          13                     Weedle        Bug     Poison        195
# 18          14                     Kakuna        Bug     Poison        205
# 19          15                   Beedrill        Bug     Poison        395
# 20          15      BeedrillMega Beedrill        Bug     Poison        495
# 21          17                  Pidgeotto     Normal     Flying        349
# 22          16                     Pidgey     Normal     Flying        251
# 23          17                  Pidgeotto     Normal     Flying        349
# 24          18                    Pidgeot     Normal     Flying        479
# 25          18        PidgeotMega Pidgeot     Normal     Flying        579
# 26          19                    Rattata     Normal        NaN        253
# 27          20                   Raticate     Normal        NaN        413
# 28          21                    Spearow     Normal     Flying        262
# 29          22                     Fearow     Normal     Flying        442
# ..         ...                        ...        ...        ...        ...
# 780        704                      Goomy     Dragon        NaN        300
# 781        705                    Sliggoo     Dragon        NaN        452
# 782        706                     Goodra     Dragon        NaN        600
# 783        707                     Klefki      Steel      Fairy        470
# 784        708                   Phantump      Ghost      Grass        309
# 785        709                  Trevenant      Ghost      Grass        474
# 786        710      PumpkabooAverage Size      Ghost      Grass        435
# 787        710        PumpkabooSmall Size      Ghost      Grass        335
# 788        710        PumpkabooLarge Size      Ghost      Grass        335
# 789        710        PumpkabooSuper Size      Ghost      Grass        335
# 790        711      GourgeistAverage Size      Ghost      Grass        494
# 791        711        GourgeistSmall Size      Ghost      Grass        494
# 792        711        GourgeistLarge Size      Ghost      Grass        494
# 793        711        GourgeistSuper Size      Ghost      Grass        494
# 794        712                   Bergmite        Ice        NaN        304
# 795        713                    Avalugg        Ice        NaN        714
# 796        714                     Noibat     Flying     Dragon        245
# 797        715                    Noivern     Flying     Dragon        535
# 798        716                    Xerneas      Fairy        NaN        680
# 799        717                    Yveltal       Dark     Flying        680
# 800        718           Zygarde50% Forme     Dragon     Ground        600
# 801        719                    Diancie       Rock      Fairy        600
# 802        719        DiancieMega Diancie       Rock      Fairy        700
# 803        720        HoopaHoopa Confined    Psychic      Ghost        600
# 804        720         HoopaHoopa Unbound    Psychic       Dark        680
# 805        721                  Volcanion       Fire      Water        600
# 806  undefined                  undefined  undefined  undefined  undefined
# 807  undefined                  undefined  undefined  undefined  undefined
# 808        NaN                        NaN        NaN        NaN        NaN
# 809        NaN                        NaN        NaN        NaN        NaN
#
#             HP     Attack    Defense    Sp. Atk    Sp. Def      Speed  \
# 0           45         49         49         65         65         45
# 1           60         62         63         80         80         60
# 2           80         82         83        100        100         80
# 3           80        100        123        122        120         80
# 4           39         52         43         60         50         65
# 5           58         64         58         80         65         80
# 6           78         84         78        109         85        100
# 7           78        130        111        130         85        100
# 8           78        104         78        159        115        100
# 9           44        840         65         50         64         43
# 10          59         63         80         65         80         58
# 11          79         83        100         85        105         78
# 12          79        103        120        135        115         78
# 13          45         30         35         20         20         45
# 14          50         20         55         25         25         30
# 15          50         20         55         25         25         30
# 16          60         45         50         90         80         70
# 17         NaN         35         30         20         20         50
# 18          45         25         50         25         25         35
# 19          65         90         40         45         80         75
# 20          65        150         40         15         80        145
# 21          63         60         55         50         50         71
# 22          40         45         40         35         35         56
# 23          63         60         55         50         50         71
# 24          83         80         75         70         70        101
# 25          83         80         80        135         80        121
# 26          30         56         35         25         35         72
# 27          55         81         60         50         70         97
# 28          40         60         30         31         31         70
# 29          65         90         65         61         61        100
# ..         ...        ...        ...        ...        ...        ...
# 780         45         50         35         55         75         40
# 781         68         75         53         83        113         60
# 782         90        100         70        110        150         80
# 783         57         80         91         80         87         75
# 784         43         70         48         50         60         38
# 785         85        110         76         65         82         56
# 786         49         66         70         44         55         51
# 787         44         66         70         44         55         56
# 788         54         66         70         44         55         46
# 789         59         66         70         44         55         41
# 790         65         90        122         58         75         84
# 791         55         85        122         58         75         99
# 792         75         95        122         58         75         69
# 793        185        100        122         58         75         54
# 794         55         69         85         32         35         28
# 795         95        117        184         44         46         28
# 796         40         30         35         45         40         55
# 797         85         70         80         97         80        123
# 798        126        131         95        131         98         99
# 799        126        131         95        131         98         99
# 800        108        100        121         81         95         95
# 801         50        100        150        100        150         50
# 802         50        160        110        160        110        110
# 803         80        110         60        150        130         70
# 804         80        160         60        170        130         80
# 805         80        110        120        130         90         70
# 806  undefined  undefined  undefined  undefined  undefined  undefined
# 807  undefined  undefined  undefined  undefined  undefined  undefined
# 808        NaN        NaN        NaN        NaN        NaN        NaN
# 809        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Generation  Legendary
# 0            1      FALSE
# 1            1      FALSE
# 2            1      FALSE
# 3            1      FALSE
# 4            1      FALSE
# 5            1      FALSE
# 6            1      FALSE
# 7            1      FALSE
# 8            1      FALSE
# 9            1      FALSE
# 10           1      FALSE
# 11       FALSE          1
# 12           1      FALSE
# 13           1      FALSE
# 14           1      FALSE
# 15           1      FALSE
# 16           1      FALSE
# 17           1      FALSE
# 18           1      FALSE
# 19           1      FALSE
# 20           1      FALSE
# 21           1      FALSE
# 22           1      FALSE
# 23           1      FALSE
# 24           1      FALSE
# 25           1      FALSE
# 26           1      FALSE
# 27           1      FALSE
# 28           1      FALSE
# 29           1      FALSE
# ..         ...        ...
# 780          6      FALSE
# 781          6      FALSE
# 782          6      FALSE
# 783          6      FALSE
# 784          6      FALSE
# 785          6      FALSE
# 786          6      FALSE
# 787          6      FALSE
# 788          6      FALSE
# 789          6      FALSE
# 790          6      FALSE
# 791          6      FALSE
# 792          6      FALSE
# 793          6      FALSE
# 794          6      FALSE
# 795          6      FALSE
# 796          6      FALSE
# 797          6      FALSE
# 798          6       TRUE
# 799          6       TRUE
# 800          6       TRUE
# 801          6       TRUE
# 802          6       TRUE
# 803          6       TRUE
# 804          6       TRUE
# 805          6       TRUE
# 806  undefined  undefined
# 807  undefined  undefined
# 808        NaN
# 809        NaN
#
# [810 rows x 13 columns]

# %%
#删除无效行
primitive_data_1=primitive_data.iloc[:-4]
primitive_data_1
# Out:
#        #                       Name    Type 1  Type 2 Total   HP Attack  \
# 0      1                  Bulbasaur     Grass  Poison   318   45     49
# 1      2                    Ivysaur     Grass  Poison   405   60     62
# 2      3                   Venusaur     Grass  Poison   525   80     82
# 3      3      VenusaurMega Venusaur     Grass  Poison   625   80    100
# 4      4                 Charmander      Fire     NaN   309   39     52
# 5      5                 Charmeleon      Fire     NaN   405   58     64
# 6      6                  Charizard      Fire  Flying   534   78     84
# 7      6  CharizardMega Charizard X      Fire  Dragon   634   78    130
# 8      6  CharizardMega Charizard Y      Fire  Flying   634   78    104
# 9      7                   Squirtle     Water     NaN   314   44    840
# 10     8                  Wartortle     Water     NaN   405   59     63
# 11     9                  Blastoise     Water     NaN   530   79     83
# 12     9    BlastoiseMega Blastoise     Water     NaN   630   79    103
# 13    10                   Caterpie       Bug     NaN   195   45     30
# 14    11                    Metapod       Bug     NaN   205   50     20
# 15    11                    Metapod       Bug     NaN   205   50     20
# 16    12                 Butterfree       Bug  Flying   395   60     45
# 17    13                     Weedle       Bug  Poison   195  NaN     35
# 18    14                     Kakuna       Bug  Poison   205   45     25
# 19    15                   Beedrill       Bug  Poison   395   65     90
# 20    15      BeedrillMega Beedrill       Bug  Poison   495   65    150
# 21    17                  Pidgeotto    Normal  Flying   349   63     60
# 22    16                     Pidgey    Normal  Flying   251   40     45
# 23    17                  Pidgeotto    Normal  Flying   349   63     60
# 24    18                    Pidgeot    Normal  Flying   479   83     80
# 25    18        PidgeotMega Pidgeot    Normal  Flying   579   83     80
# 26    19                    Rattata    Normal     NaN   253   30     56
# 27    20                   Raticate    Normal     NaN   413   55     81
# 28    21                    Spearow    Normal  Flying   262   40     60
# 29    22                     Fearow    Normal  Flying   442   65     90
# ..   ...                        ...       ...     ...   ...  ...    ...
# 776  700                    Sylveon     Fairy     NaN   525   95     65
# 777  701                   Hawlucha  Fighting  Flying   500   78     92
# 778  702                    Dedenne  Electric   Fairy   431   67     58
# 779  703                    Carbink      Rock   Fairy   500   50     50
# 780  704                      Goomy    Dragon     NaN   300   45     50
# 781  705                    Sliggoo    Dragon     NaN   452   68     75
# 782  706                     Goodra    Dragon     NaN   600   90    100
# 783  707                     Klefki     Steel   Fairy   470   57     80
# 784  708                   Phantump     Ghost   Grass   309   43     70
# 785  709                  Trevenant     Ghost   Grass   474   85    110
# 786  710      PumpkabooAverage Size     Ghost   Grass   435   49     66
# 787  710        PumpkabooSmall Size     Ghost   Grass   335   44     66
# 788  710        PumpkabooLarge Size     Ghost   Grass   335   54     66
# 789  710        PumpkabooSuper Size     Ghost   Grass   335   59     66
# 790  711      GourgeistAverage Size     Ghost   Grass   494   65     90
# 791  711        GourgeistSmall Size     Ghost   Grass   494   55     85
# 792  711        GourgeistLarge Size     Ghost   Grass   494   75     95
# 793  711        GourgeistSuper Size     Ghost   Grass   494  185    100
# 794  712                   Bergmite       Ice     NaN   304   55     69
# 795  713                    Avalugg       Ice     NaN   714   95    117
# 796  714                     Noibat    Flying  Dragon   245   40     30
# 797  715                    Noivern    Flying  Dragon   535   85     70
# 798  716                    Xerneas     Fairy     NaN   680  126    131
# 799  717                    Yveltal      Dark  Flying   680  126    131
# 800  718           Zygarde50% Forme    Dragon  Ground   600  108    100
# 801  719                    Diancie      Rock   Fairy   600   50    100
# 802  719        DiancieMega Diancie      Rock   Fairy   700   50    160
# 803  720        HoopaHoopa Confined   Psychic   Ghost   600   80    110
# 804  720         HoopaHoopa Unbound   Psychic    Dark   680   80    160
# 805  721                  Volcanion      Fire   Water   600   80    110
#
#     Defense Sp. Atk Sp. Def Speed Generation Legendary
# 0        49      65      65    45          1     FALSE
# 1        63      80      80    60          1     FALSE
# 2        83     100     100    80          1     FALSE
# 3       123     122     120    80          1     FALSE
# 4        43      60      50    65          1     FALSE
# 5        58      80      65    80          1     FALSE
# 6        78     109      85   100          1     FALSE
# 7       111     130      85   100          1     FALSE
# 8        78     159     115   100          1     FALSE
# 9        65      50      64    43          1     FALSE
# 10       80      65      80    58          1     FALSE
# 11      100      85     105    78      FALSE         1
# 12      120     135     115    78          1     FALSE
# 13       35      20      20    45          1     FALSE
# 14       55      25      25    30          1     FALSE
# 15       55      25      25    30          1     FALSE
# 16       50      90      80    70          1     FALSE
# 17       30      20      20    50          1     FALSE
# 18       50      25      25    35          1     FALSE
# 19       40      45      80    75          1     FALSE
# 20       40      15      80   145          1     FALSE
# 21       55      50      50    71          1     FALSE
# 22       40      35      35    56          1     FALSE
# 23       55      50      50    71          1     FALSE
# 24       75      70      70   101          1     FALSE
# 25       80     135      80   121          1     FALSE
# 26       35      25      35    72          1     FALSE
# 27       60      50      70    97          1     FALSE
# 28       30      31      31    70          1     FALSE
# 29       65      61      61   100          1     FALSE
# ..      ...     ...     ...   ...        ...       ...
# 776      65     110     130    60          6     FALSE
# 777      75      74      63   118          6     FALSE
# 778      57      81      67   101          6     FALSE
# 779     150      50     150    50          6     FALSE
# 780      35      55      75    40          6     FALSE
# 781      53      83     113    60          6     FALSE
# 782      70     110     150    80          6     FALSE
# 783      91      80      87    75          6     FALSE
# 784      48      50      60    38          6     FALSE
# 785      76      65      82    56          6     FALSE
# 786      70      44      55    51          6     FALSE
# 787      70      44      55    56          6     FALSE
# 788      70      44      55    46          6     FALSE
# 789      70      44      55    41          6     FALSE
# 790     122      58      75    84          6     FALSE
# 791     122      58      75    99          6     FALSE
# 792     122      58      75    69          6     FALSE
# 793     122      58      75    54          6     FALSE
# 794      85      32      35    28          6     FALSE
# 795     184      44      46    28          6     FALSE
# 796      35      45      40    55          6     FALSE
# 797      80      97      80   123          6     FALSE
# 798      95     131      98    99          6      TRUE
# 799      95     131      98    99          6      TRUE
# 800     121      81      95    95          6      TRUE
# 801     150     100     150    50          6      TRUE
# 802     110     160     110   110          6      TRUE
# 803      60     150     130    70          6      TRUE
# 804      60     170     130    80          6      TRUE
# 805     120     130      90    70          6      TRUE
#
# [806 rows x 13 columns]

# %%
#列出重复行
primitive_data_1[primitive_data_1.duplicated()]
# Out:
#        #       Name  Type 1  Type 2 Total  HP Attack Defense Sp. Atk Sp. Def  \
# 15    11    Metapod     Bug     NaN   205  50     20      55      25      25
# 23    17  Pidgeotto  Normal  Flying   349  63     60      55      50      50
# 185  168    Ariados     Bug  Poison   390  70     90      70      60      60
# 186  168    Ariados     Bug  Poison   390  70     90      70      60      60
# 187  168    Ariados     Bug  Poison   390  70     90      70      60      60
#
#     Speed Generation Legendary
# 15     30          1     FALSE
# 23     71          1     FALSE
# 185    40          2     FALSE
# 186    40          2     FALSE
# 187    40          2     FALSE

# %%
#删除重复行
primitive_data_1=primitive_data_1.drop_duplicates()
primitive_data_1
# Out:
#        #                       Name    Type 1  Type 2 Total   HP Attack  \
# 0      1                  Bulbasaur     Grass  Poison   318   45     49
# 1      2                    Ivysaur     Grass  Poison   405   60     62
# 2      3                   Venusaur     Grass  Poison   525   80     82
# 3      3      VenusaurMega Venusaur     Grass  Poison   625   80    100
# 4      4                 Charmander      Fire     NaN   309   39     52
# 5      5                 Charmeleon      Fire     NaN   405   58     64
# 6      6                  Charizard      Fire  Flying   534   78     84
# 7      6  CharizardMega Charizard X      Fire  Dragon   634   78    130
# 8      6  CharizardMega Charizard Y      Fire  Flying   634   78    104
# 9      7                   Squirtle     Water     NaN   314   44    840
# 10     8                  Wartortle     Water     NaN   405   59     63
# 11     9                  Blastoise     Water     NaN   530   79     83
# 12     9    BlastoiseMega Blastoise     Water     NaN   630   79    103
# 13    10                   Caterpie       Bug     NaN   195   45     30
# 14    11                    Metapod       Bug     NaN   205   50     20
# 16    12                 Butterfree       Bug  Flying   395   60     45
# 17    13                     Weedle       Bug  Poison   195  NaN     35
# 18    14                     Kakuna       Bug  Poison   205   45     25
# 19    15                   Beedrill       Bug  Poison   395   65     90
# 20    15      BeedrillMega Beedrill       Bug  Poison   495   65    150
# 21    17                  Pidgeotto    Normal  Flying   349   63     60
# 22    16                     Pidgey    Normal  Flying   251   40     45
# 24    18                    Pidgeot    Normal  Flying   479   83     80
# 25    18        PidgeotMega Pidgeot    Normal  Flying   579   83     80
# 26    19                    Rattata    Normal     NaN   253   30     56
# 27    20                   Raticate    Normal     NaN   413   55     81
# 28    21                    Spearow    Normal  Flying   262   40     60
# 29    22                     Fearow    Normal  Flying   442   65     90
# 30    23                      Ekans    Poison     NaN   288   35     60
# 31    24                      Arbok    Poison     NaN   438   60     85
# ..   ...                        ...       ...     ...   ...  ...    ...
# 776  700                    Sylveon     Fairy     NaN   525   95     65
# 777  701                   Hawlucha  Fighting  Flying   500   78     92
# 778  702                    Dedenne  Electric   Fairy   431   67     58
# 779  703                    Carbink      Rock   Fairy   500   50     50
# 780  704                      Goomy    Dragon     NaN   300   45     50
# 781  705                    Sliggoo    Dragon     NaN   452   68     75
# 782  706                     Goodra    Dragon     NaN   600   90    100
# 783  707                     Klefki     Steel   Fairy   470   57     80
# 784  708                   Phantump     Ghost   Grass   309   43     70
# 785  709                  Trevenant     Ghost   Grass   474   85    110
# 786  710      PumpkabooAverage Size     Ghost   Grass   435   49     66
# 787  710        PumpkabooSmall Size     Ghost   Grass   335   44     66
# 788  710        PumpkabooLarge Size     Ghost   Grass   335   54     66
# 789  710        PumpkabooSuper Size     Ghost   Grass   335   59     66
# 790  711      GourgeistAverage Size     Ghost   Grass   494   65     90
# 791  711        GourgeistSmall Size     Ghost   Grass   494   55     85
# 792  711        GourgeistLarge Size     Ghost   Grass   494   75     95
# 793  711        GourgeistSuper Size     Ghost   Grass   494  185    100
# 794  712                   Bergmite       Ice     NaN   304   55     69
# 795  713                    Avalugg       Ice     NaN   714   95    117
# 796  714                     Noibat    Flying  Dragon   245   40     30
# 797  715                    Noivern    Flying  Dragon   535   85     70
# 798  716                    Xerneas     Fairy     NaN   680  126    131
# 799  717                    Yveltal      Dark  Flying   680  126    131
# 800  718           Zygarde50% Forme    Dragon  Ground   600  108    100
# 801  719                    Diancie      Rock   Fairy   600   50    100
# 802  719        DiancieMega Diancie      Rock   Fairy   700   50    160
# 803  720        HoopaHoopa Confined   Psychic   Ghost   600   80    110
# 804  720         HoopaHoopa Unbound   Psychic    Dark   680   80    160
# 805  721                  Volcanion      Fire   Water   600   80    110
#
#     Defense Sp. Atk Sp. Def Speed Generation Legendary
# 0        49      65      65    45          1     FALSE
# 1        63      80      80    60          1     FALSE
# 2        83     100     100    80          1     FALSE
# 3       123     122     120    80          1     FALSE
# 4        43      60      50    65          1     FALSE
# 5        58      80      65    80          1     FALSE
# 6        78     109      85   100          1     FALSE
# 7       111     130      85   100          1     FALSE
# 8        78     159     115   100          1     FALSE
# 9        65      50      64    43          1     FALSE
# 10       80      65      80    58          1     FALSE
# 11      100      85     105    78      FALSE         1
# 12      120     135     115    78          1     FALSE
# 13       35      20      20    45          1     FALSE
# 14       55      25      25    30          1     FALSE
# 16       50      90      80    70          1     FALSE
# 17       30      20      20    50          1     FALSE
# 18       50      25      25    35          1     FALSE
# 19       40      45      80    75          1     FALSE
# 20       40      15      80   145          1     FALSE
# 21       55      50      50    71          1     FALSE
# 22       40      35      35    56          1     FALSE
# 24       75      70      70   101          1     FALSE
# 25       80     135      80   121          1     FALSE
# 26       35      25      35    72          1     FALSE
# 27       60      50      70    97          1     FALSE
# 28       30      31      31    70          1     FALSE
# 29       65      61      61   100          1     FALSE
# 30       44      40      54    55          1     FALSE
# 31       69      65      79    80          1     FALSE
# ..      ...     ...     ...   ...        ...       ...
# 776      65     110     130    60          6     FALSE
# 777      75      74      63   118          6     FALSE
# 778      57      81      67   101          6     FALSE
# 779     150      50     150    50          6     FALSE
# 780      35      55      75    40          6     FALSE
# 781      53      83     113    60          6     FALSE
# 782      70     110     150    80          6     FALSE
# 783      91      80      87    75          6     FALSE
# 784      48      50      60    38          6     FALSE
# 785      76      65      82    56          6     FALSE
# 786      70      44      55    51          6     FALSE
# 787      70      44      55    56          6     FALSE
# 788      70      44      55    46          6     FALSE
# 789      70      44      55    41          6     FALSE
# 790     122      58      75    84          6     FALSE
# 791     122      58      75    99          6     FALSE
# 792     122      58      75    69          6     FALSE
# 793     122      58      75    54          6     FALSE
# 794      85      32      35    28          6     FALSE
# 795     184      44      46    28          6     FALSE
# 796      35      45      40    55          6     FALSE
# 797      80      97      80   123          6     FALSE
# 798      95     131      98    99          6      TRUE
# 799      95     131      98    99          6      TRUE
# 800     121      81      95    95          6      TRUE
# 801     150     100     150    50          6      TRUE
# 802     110     160     110   110          6      TRUE
# 803      60     150     130    70          6      TRUE
# 804      60     170     130    80          6      TRUE
# 805     120     130      90    70          6      TRUE
#
# [801 rows x 13 columns]

# %%
nan_rows_first_column=primitive_data_1[primitive_data_1.iloc[:,0].isnull()]
nan_rows_first_column
# Out:
#        # Name Type 1 Type 2 Total   HP Attack Defense Sp. Atk Sp. Def Speed  \
# 408  NaN  NaN    NaN    NaN   NaN  NaN    NaN     NaN     NaN     NaN   NaN
#
#     Generation Legendary
# 408        NaN       NaN

# %%
primitive_data_1=primitive_data_1.drop([408])
primitive_data_1
# Out:
#        #                       Name    Type 1  Type 2 Total   HP Attack  \
# 0      1                  Bulbasaur     Grass  Poison   318   45     49
# 1      2                    Ivysaur     Grass  Poison   405   60     62
# 2      3                   Venusaur     Grass  Poison   525   80     82
# 3      3      VenusaurMega Venusaur     Grass  Poison   625   80    100
# 4      4                 Charmander      Fire     NaN   309   39     52
# 5      5                 Charmeleon      Fire     NaN   405   58     64
# 6      6                  Charizard      Fire  Flying   534   78     84
# 7      6  CharizardMega Charizard X      Fire  Dragon   634   78    130
# 8      6  CharizardMega Charizard Y      Fire  Flying   634   78    104
# 9      7                   Squirtle     Water     NaN   314   44    840
# 10     8                  Wartortle     Water     NaN   405   59     63
# 11     9                  Blastoise     Water     NaN   530   79     83
# 12     9    BlastoiseMega Blastoise     Water     NaN   630   79    103
# 13    10                   Caterpie       Bug     NaN   195   45     30
# 14    11                    Metapod       Bug     NaN   205   50     20
# 16    12                 Butterfree       Bug  Flying   395   60     45
# 17    13                     Weedle       Bug  Poison   195  NaN     35
# 18    14                     Kakuna       Bug  Poison   205   45     25
# 19    15                   Beedrill       Bug  Poison   395   65     90
# 20    15      BeedrillMega Beedrill       Bug  Poison   495   65    150
# 21    17                  Pidgeotto    Normal  Flying   349   63     60
# 22    16                     Pidgey    Normal  Flying   251   40     45
# 24    18                    Pidgeot    Normal  Flying   479   83     80
# 25    18        PidgeotMega Pidgeot    Normal  Flying   579   83     80
# 26    19                    Rattata    Normal     NaN   253   30     56
# 27    20                   Raticate    Normal     NaN   413   55     81
# 28    21                    Spearow    Normal  Flying   262   40     60
# 29    22                     Fearow    Normal  Flying   442   65     90
# 30    23                      Ekans    Poison     NaN   288   35     60
# 31    24                      Arbok    Poison     NaN   438   60     85
# ..   ...                        ...       ...     ...   ...  ...    ...
# 776  700                    Sylveon     Fairy     NaN   525   95     65
# 777  701                   Hawlucha  Fighting  Flying   500   78     92
# 778  702                    Dedenne  Electric   Fairy   431   67     58
# 779  703                    Carbink      Rock   Fairy   500   50     50
# 780  704                      Goomy    Dragon     NaN   300   45     50
# 781  705                    Sliggoo    Dragon     NaN   452   68     75
# 782  706                     Goodra    Dragon     NaN   600   90    100
# 783  707                     Klefki     Steel   Fairy   470   57     80
# 784  708                   Phantump     Ghost   Grass   309   43     70
# 785  709                  Trevenant     Ghost   Grass   474   85    110
# 786  710      PumpkabooAverage Size     Ghost   Grass   435   49     66
# 787  710        PumpkabooSmall Size     Ghost   Grass   335   44     66
# 788  710        PumpkabooLarge Size     Ghost   Grass   335   54     66
# 789  710        PumpkabooSuper Size     Ghost   Grass   335   59     66
# 790  711      GourgeistAverage Size     Ghost   Grass   494   65     90
# 791  711        GourgeistSmall Size     Ghost   Grass   494   55     85
# 792  711        GourgeistLarge Size     Ghost   Grass   494   75     95
# 793  711        GourgeistSuper Size     Ghost   Grass   494  185    100
# 794  712                   Bergmite       Ice     NaN   304   55     69
# 795  713                    Avalugg       Ice     NaN   714   95    117
# 796  714                     Noibat    Flying  Dragon   245   40     30
# 797  715                    Noivern    Flying  Dragon   535   85     70
# 798  716                    Xerneas     Fairy     NaN   680  126    131
# 799  717                    Yveltal      Dark  Flying   680  126    131
# 800  718           Zygarde50% Forme    Dragon  Ground   600  108    100
# 801  719                    Diancie      Rock   Fairy   600   50    100
# 802  719        DiancieMega Diancie      Rock   Fairy   700   50    160
# 803  720        HoopaHoopa Confined   Psychic   Ghost   600   80    110
# 804  720         HoopaHoopa Unbound   Psychic    Dark   680   80    160
# 805  721                  Volcanion      Fire   Water   600   80    110
#
#     Defense Sp. Atk Sp. Def Speed Generation Legendary
# 0        49      65      65    45          1     FALSE
# 1        63      80      80    60          1     FALSE
# 2        83     100     100    80          1     FALSE
# 3       123     122     120    80          1     FALSE
# 4        43      60      50    65          1     FALSE
# 5        58      80      65    80          1     FALSE
# 6        78     109      85   100          1     FALSE
# 7       111     130      85   100          1     FALSE
# 8        78     159     115   100          1     FALSE
# 9        65      50      64    43          1     FALSE
# 10       80      65      80    58          1     FALSE
# 11      100      85     105    78      FALSE         1
# 12      120     135     115    78          1     FALSE
# 13       35      20      20    45          1     FALSE
# 14       55      25      25    30          1     FALSE
# 16       50      90      80    70          1     FALSE
# 17       30      20      20    50          1     FALSE
# 18       50      25      25    35          1     FALSE
# 19       40      45      80    75          1     FALSE
# 20       40      15      80   145          1     FALSE
# 21       55      50      50    71          1     FALSE
# 22       40      35      35    56          1     FALSE
# 24       75      70      70   101          1     FALSE
# 25       80     135      80   121          1     FALSE
# 26       35      25      35    72          1     FALSE
# 27       60      50      70    97          1     FALSE
# 28       30      31      31    70          1     FALSE
# 29       65      61      61   100          1     FALSE
# 30       44      40      54    55          1     FALSE
# 31       69      65      79    80          1     FALSE
# ..      ...     ...     ...   ...        ...       ...
# 776      65     110     130    60          6     FALSE
# 777      75      74      63   118          6     FALSE
# 778      57      81      67   101          6     FALSE
# 779     150      50     150    50          6     FALSE
# 780      35      55      75    40          6     FALSE
# 781      53      83     113    60          6     FALSE
# 782      70     110     150    80          6     FALSE
# 783      91      80      87    75          6     FALSE
# 784      48      50      60    38          6     FALSE
# 785      76      65      82    56          6     FALSE
# 786      70      44      55    51          6     FALSE
# 787      70      44      55    56          6     FALSE
# 788      70      44      55    46          6     FALSE
# 789      70      44      55    41          6     FALSE
# 790     122      58      75    84          6     FALSE
# 791     122      58      75    99          6     FALSE
# 792     122      58      75    69          6     FALSE
# 793     122      58      75    54          6     FALSE
# 794      85      32      35    28          6     FALSE
# 795     184      44      46    28          6     FALSE
# 796      35      45      40    55          6     FALSE
# 797      80      97      80   123          6     FALSE
# 798      95     131      98    99          6      TRUE
# 799      95     131      98    99          6      TRUE
# 800     121      81      95    95          6      TRUE
# 801     150     100     150    50          6      TRUE
# 802     110     160     110   110          6      TRUE
# 803      60     150     130    70          6      TRUE
# 804      60     170     130    80          6      TRUE
# 805     120     130      90    70          6      TRUE
#
# [800 rows x 13 columns]

# %%
nan_rows_first_column=primitive_data_1[primitive_data_1.iloc[:,2].isnull()]
nan_rows_first_column
# Out:
#      #              Name Type 1 Type 2 Total  HP Attack Defense Sp. Atk  \
# 39  32  Nidoranâ?Poison    NaN    273    46  57     40      40      40
#
#    Sp. Def Speed Generation Legendary
# 39      50     1      FALSE       NaN

# %%
primitive_data_1.iloc[:,2]=primitive_data_1.iloc[:,2].fillna('Unknown')

# %%
nan_rows_first_column=primitive_data_1[primitive_data_1.iloc[:,3].isnull()]
nan_rows_first_column
# Out:
#        #                     Name    Type 1 Type 2 Total    HP Attack Defense  \
# 4      4               Charmander      Fire    NaN   309    39     52      43
# 5      5               Charmeleon      Fire    NaN   405    58     64      58
# 9      7                 Squirtle     Water    NaN   314    44    840      65
# 10     8                Wartortle     Water    NaN   405    59     63      80
# 11     9                Blastoise     Water    NaN   530    79     83     100
# 12     9  BlastoiseMega Blastoise     Water    NaN   630    79    103     120
# 13    10                 Caterpie       Bug    NaN   195    45     30      35
# 14    11                  Metapod       Bug    NaN   205    50     20      55
# 26    19                  Rattata    Normal    NaN   253    30     56      35
# 27    20                 Raticate    Normal    NaN   413    55     81      60
# 30    23                    Ekans    Poison    NaN   288    35     60      44
# 31    24                    Arbok    Poison    NaN   438    60     85      69
# 32    25                  Pikachu  Electric    NaN   320    35     55      40
# 33    26                   Raichu  Electric    NaN   485    60     90      55
# 35    28                Sandslash    Ground    NaN   450    75    100     110
# 36    29               Nidoranâ    Poison    NaN   275    55     47      52
# 37    30                 Nidorina    Poison    NaN   365    70     62      67
# 40    33                 Nidorino    Poison    NaN   365    61     72      57
# 42    35                 Clefairy     Fairy    NaN   323    70     45      48
# 43    36                 Clefable     Fairy    NaN   483    95     70      73
# 44    37                   Vulpix      Fire    NaN   299    38     41      40
# 45    38                Ninetales      Fire    NaN   505    73     76      75
# 57    50                  Diglett    Ground    NaN   265    10     55      25
# 58    51                  Dugtrio    Ground    NaN   405    35     80      50
# 59    52                   Meowth    Normal    NaN   290    40     45      35
# 60    53                  Persian    Normal    NaN   440    65     70      60
# 61    54                  Psyduck     Water    NaN   320    50     52      48
# 62    55                  Golduck     Water    NaN   500   120     82      78
# 63    56                   Mankey  Fighting    NaN   305    40     80      35
# 64    57                 Primeape  Fighting    NaN   455    65    105      60
# ..   ...                      ...       ...    ...   ...   ...    ...     ...
# 727  653                 Fennekin      Fire    NaN   307    40     45      40
# 728  654                  Braixen      Fire    NaN   409    59     59      58
# 730  656                  Froakie     Water    NaN   314    41     56      40
# 731  657                Frogadier     Water    NaN   405    54     63      52
# 733  659                 Bunnelby    Normal    NaN   237    38     36      38
# 738  664               Scatterbug       Bug    NaN   200    38     35      40
# 739  665                   Spewpa       Bug    NaN   213    45     22      60
# 743  669                FlabÃ©bÃ©     Fairy    NaN   303    44     38      39
# 744  670                  Floette     Fairy    NaN   371    54     45      47
# 745  671                  Florges     Fairy    NaN   552    78     65      68
# 746  672                   Skiddo     Grass    NaN   350    66     65      48
# 747  673                   Gogoat     Grass    NaN   531   123    100      62
# 748  674                  Pancham  Fighting    NaN   348    67     82      62
# 750  676                  Furfrou    Normal    NaN   472    75     80      60
# 751  677                   Espurr   Psychic    NaN   355    62     48      54
# 752  678             MeowsticMale   Psychic    NaN   466    74     48      76
# 753  678           MeowsticFemale   Psychic    NaN   466    74     48      76
# 758  682                 Spritzee     Fairy    NaN   341    78     52      60
# 759  683               Aromatisse     Fairy    NaN   462   101     72      72
# 760  684                  Swirlix     Fairy    NaN   341    62     48      66
# 761  685                 Slurpuff     Fairy    NaN   480    82     80      86
# 768  692                Clauncher     Water    NaN   330  50.1     53      62
# 769  693                Clawitzer     Water    NaN   500    71     73      88
# 776  700                  Sylveon     Fairy    NaN   525    95     65      65
# 780  704                    Goomy    Dragon    NaN   300    45     50      35
# 781  705                  Sliggoo    Dragon    NaN   452    68     75      53
# 782  706                   Goodra    Dragon    NaN   600    90    100      70
# 794  712                 Bergmite       Ice    NaN   304    55     69      85
# 795  713                  Avalugg       Ice    NaN   714    95    117     184
# 798  716                  Xerneas     Fairy    NaN   680   126    131      95
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 4        60      50    65          1     FALSE
# 5        80      65    80          1     FALSE
# 9        50      64    43          1     FALSE
# 10       65      80    58          1     FALSE
# 11       85     105    78      FALSE         1
# 12      135     115    78          1     FALSE
# 13       20      20    45          1     FALSE
# 14       25      25    30          1     FALSE
# 26       25      35    72          1     FALSE
# 27       50      70    97          1     FALSE
# 30       40      54    55          1     FALSE
# 31       65      79    80          1     FALSE
# 32       50      50    90      FALSE         0
# 33       90      80   110          1     FALSE
# 35       45      55    65          1     FALSE
# 36       40      40    41          1     FALSE
# 37       55      55    56          1     FALSE
# 40       55      55    65          1     FALSE
# 42       60      65    35          1     FALSE
# 43       95      90    60          1     FALSE
# 44       50      65    65          1     FALSE
# 45       81     100   100          1         0
# 57       35      45    95          1     FALSE
# 58       50      70   120          1     FALSE
# 59       40      40    90          1     FALSE
# 60       65      65   115          1     FALSE
# 61       65      50    55          1     FALSE
# 62       95      80    85          1     FALSE
# 63       35      45    70          1     FALSE
# 64       60      70    95          1     FALSE
# ..      ...     ...   ...        ...       ...
# 727      62      60    60          6     FALSE
# 728      90      70    73          6     FALSE
# 730      62      44    71          6     FALSE
# 731      83      56    97          6     FALSE
# 733      32      36    57          6     FALSE
# 738      27      25    35          6     FALSE
# 739      27      30    29          6     FALSE
# 743      61      79    42          6     FALSE
# 744      75      98    52          6     FALSE
# 745     112     154    75          6     FALSE
# 746      62      57    52          6     FALSE
# 747      97      81    68          6     FALSE
# 748      46      48    43          6     FALSE
# 750      65      90   102          6     FALSE
# 751      63      60    68          6     FALSE
# 752      83      81   104          6     FALSE
# 753      83      81   104          6     FALSE
# 758      63      65    23          6     FALSE
# 759      99      89    29          6     FALSE
# 760      59      57    49          6     FALSE
# 761      85      75    72          6     FALSE
# 768      58      63    44          6     FALSE
# 769     120      89    59          6     FALSE
# 776     110     130    60          6     FALSE
# 780      55      75    40          6     FALSE
# 781      83     113    60          6     FALSE
# 782     110     150    80          6     FALSE
# 794      32      35    28          6     FALSE
# 795      44      46    28          6     FALSE
# 798     131      98    99          6      TRUE
#
# [382 rows x 13 columns]

# %%
primitive_data_1.iloc[:,2]=primitive_data_1.iloc[:,3].fillna('Unknown')

# %%
nan_rows_first_column=primitive_data_1[primitive_data_1.iloc[:,5].isnull()]
nan_rows_first_column
# Out:
#      #    Name  Type 1  Type 2 Total   HP Attack Defense Sp. Atk Sp. Def  \
# 17  13  Weedle  Poison  Poison   195  NaN     35      30      20      20
#
#    Speed Generation Legendary
# 17    50          1     FALSE

# %%
#转化为float类型
primitive_data_1.iloc[:,5]=primitive_data_1.iloc[:,5].astype(float)

# %%
#填充平均值
primitive_data_1.iloc[:,5]=primitive_data_1.iloc[:,5].fillna(primitive_data_1.iloc[:,5].mean())

# %%
#确保填充完成
nan_rows_first_column=primitive_data_1[primitive_data_1.iloc[:,5].isnull()]
nan_rows_first_column
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
primitive_data_1.iloc[:,5]=primitive_data_1.iloc[:,5].astype(int)

# %%
primitive_data_1.iloc[:,0]=primitive_data_1.iloc[:,0].astype(int)
primitive_data_1.iloc[:,4]=primitive_data_1.iloc[:,4].astype(int)
primitive_data_1.iloc[:,6]=primitive_data_1.iloc[:,6].astype(float)
primitive_data_1.iloc[:,7]=primitive_data_1.iloc[:,7].astype(int)
primitive_data_1.iloc[:,8]=primitive_data_1.iloc[:,8].astype(float)
primitive_data_1.iloc[:,9]=primitive_data_1.iloc[:,9].astype(float)
primitive_data_1.iloc[:,10]=primitive_data_1.iloc[:,10].astype(int)

# %%
import matplotlib.pyplot as plt
plt.scatter(range(0,primitive_data_1.shape[0]),primitive_data_1.iloc[:,6])
plt.show()

# %%
import numpy as np
Q1=primitive_data_1.iloc[:,6].quantile(0.25)
Q3=primitive_data_1.iloc[:,6].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

outliers=primitive_data_1[(primitive_data_1.iloc[:,6]<lower_bound)|(primitive_data_1.iloc[:,6]>upper_bound)]
print(outliers)
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 9      7                 Squirtle   Unknown       NaN    314   44   840.0
# 140  128                   Tauros   Unknown       NaN    490   75  1000.0
# 165  150      MewtwoMega Mewtwo X  Fighting  Fighting    780  106   190.0
# 237  214  HeracrossMega Heracross  Fighting  Fighting    600   80   185.0
# 430  383    GroudonPrimal Groudon      Fire      Fire    770  100   180.0
# 432  384    RayquazaMega Rayquaza    Flying    Flying    780  105   180.0
# 435  386       DeoxysAttack Forme   Unknown       NaN    600   50   180.0
# 500  445    GarchompMega Garchomp    Ground    Ground    700  108   170.0
# 717  646       KyuremBlack Kyurem       Ice       Ice    700  125   170.0
#
#      Defense  Sp. Atk  Sp. Def  Speed Generation Legendary
# 9         65     50.0     64.0     43          1     FALSE
# 140       95     40.0     70.0    110          1     FALSE
# 165      100    154.0    100.0    130          1      TRUE
# 237      115     40.0    105.0     75          2     FALSE
# 430      160    150.0     90.0     90          3      TRUE
# 432      100    180.0    100.0    115          3      TRUE
# 435       20    180.0     20.0    150          3      TRUE
# 500      115    120.0     95.0     92          4     FALSE
# 717      100    120.0     90.0     95          5      TRUE

# %%
column_mean=primitive_data_1.iloc[:,6][(primitive_data_1.index!=9)&(primitive_data_1.index!=140)].mean()
primitive_data_1.iloc[9,6]=column_mean

# %%
column_mean=primitive_data_1.iloc[:,6][(primitive_data_1.index!=9)&(primitive_data_1.index!=140)].mean()
primitive_data_1.iloc[138,6]=column_mean
primitive_data_1.iloc[138,6]
# Out:
# 78.992481203007515

# %%
import matplotlib.pyplot as plt
plt.scatter(range(0,primitive_data_1.shape[0]),primitive_data_1.iloc[:,6])
plt.show()

# %%
# %matplotlib inline
primitive_data_1["Type 2"].value_counts().plot(kind='bar')

# %%
primitive_data_1.loc[primitive_data_1["Type 2"]=="273",primitive_data_1.columns[3]]="Unknown"
primitive_data_1.loc[primitive_data_1["Type 2"]=="A",primitive_data_1.columns[3]]="Unknown"
primitive_data_1.loc[primitive_data_1["Type 2"]=="BBB",primitive_data_1.columns[3]]="Unknown"
primitive_data_1.loc[primitive_data_1["Type 2"]=="0",primitive_data_1.columns[3]]="Unknown"

# %%
# %matplotlib inline
primitive_data_1["Type 2"].value_counts().plot(kind='bar')

# %%
# %matplotlib inline
primitive_data_1["Legendary"].value_counts().plot(kind='bar')

# %%
# %matplotlib inline
primitive_data_1["Generation"].value_counts().plot(kind='bar')

# %%
primitive_data_1.loc[primitive_data_1["Legendary"]=="0",primitive_data_1.columns[12]]="FALSE"
out2=primitive_data_1[
    (primitive_data_1["Legendary"].isin(["0","1"]))&
    (primitive_data_1["Generation"].isin(["TRUE","FALSE"]))
]
out2
# Out:
#     #       Name   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 11  9  Blastoise  Unknown    NaN    530  79    83.0      100     85.0
#
#     Sp. Def  Speed Generation Legendary
# 11    105.0     78      FALSE         1

# %%
primitive_data_1.loc[primitive_data_1["Legendary"]=="1",primitive_data_1.columns[12]]="FALSE"
primitive_data_1.loc[primitive_data_1["Legendary"]=="1",primitive_data_1.columns[11]]="1"

# %%
primitive_data_1.loc[primitive_data_1["Legendary"]=="Poison",primitive_data_1.columns[12]]="FALSE"
primitive_data_1.loc[primitive_data_1["Legendary"]=="Ground",primitive_data_1.columns[12]]="FALSE"

# %%
primitive_data_1.loc[primitive_data_1["Generation"]=="undefined",primitive_data_1.columns[11]]="1"

# %%
# %matplotlib inline
primitive_data_1["Legendary"].value_counts().plot(kind='bar')

# %%
primitive_data_1.loc[primitive_data_1["Generation"]=="FALSE",primitive_data_1.columns[11]]="1"

# %%
# %matplotlib inline
primitive_data_1["Generation"].value_counts().plot(kind='bar')
