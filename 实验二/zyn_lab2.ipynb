# %%
primitive_data_1.iloc[:,11] = primitive_data_1.iloc[:, 11].astype(int)
primitive_data_1.iloc[:,12] = primitive_data_1.iloc[:, 12].astype(bool)

# %%
primitive_data_1
# Out:
#        #                       Name    Type 1   Type 2  Total   HP  \
# 0      1                  Bulbasaur     Grass   Poison    318   45
# 1      2                    Ivysaur     Grass   Poison    405   60
# 2      3                   Venusaur     Grass   Poison    525   80
# 3      3      VenusaurMega Venusaur     Grass   Poison    625   80
# 4      4                 Charmander      Fire  Unknown    309   39
# 5      5                 Charmeleon      Fire  Unknown    405   58
# 6      6                  Charizard      Fire   Flying    534   78
# 7      6  CharizardMega Charizard X      Fire   Dragon    634   78
# 8      6  CharizardMega Charizard Y      Fire   Flying    634   78
# 9      7                   Squirtle     Water  Unknown    314   44
# 10     8                  Wartortle     Water  Unknown    405   59
# 11     9                  Blastoise     Water  Unknown    530   79
# 12     9    BlastoiseMega Blastoise     Water  Unknown    630   79
# ...
